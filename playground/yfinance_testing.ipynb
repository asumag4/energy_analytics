# %% [markdown]
# ## YFinance API Testing
#
# This notebook serves as the playground (testing) environment for yfinance API.
#
# We'll be calling the API on notable oil and gas industry market markers. For pre-liminary testing and as an MVP, we'll use:
#
# Energy Sector ETFs (Broard Market Tracking):
# - XLE (Energy Select Sector SPDR Fund):
# - VDE (Vanguard Eenrgy ETF)
# - IXC (iShares Global Energy ETF)
#
# Energy Infrastructure & MLP Tickers
# - AMLP (Alerian MLP ETF)
# - OIH (VanEck Oil Services ETF)
# - XOP (SPDR S&P Oil & Gas Exploration & Production ETF)
#
# Energy Indices:
# - ^GSPE (S&P 500 Energy)
# - ^NYE (NYSE Energy Sector Index)
# - &DJUSEN (Dow Jones U.S. OIl & Gas Index)
#
# Commodity Futures:
# - CL=F (Crude Oil Futures)
# - BZ=F (Brent Crude Oil Futures)
# - NG=F (Natural Gas Futures)
